# %%
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import scipy.integrate
import time

import jax
import jax.numpy as jnp
import jax.scipy as jsp
import diffrax
from jax.scipy import optimize

# %%
WL00001 = np.load('WLul138_eta=00001.npy')
biasL00001 = np.load('biasLul138_eta=00001.npy')
costL00001 = np.load('costLul138_eta=00001.npy')
training_success_list00001 = np.load('training_success_listul138_eta=00001.npy')
success_list00001 = np.load('success_listul138_eta=00001.npy')

WL0001 = np.load('WLul138_eta=0001.npy')
biasL0001 = np.load('biasLul138_eta=0001.npy')
costL0001 = np.load('costLul138_eta=0001.npy')
training_success_list0001 = np.load('training_success_listul138_eta=0001.npy')
success_list0001 = np.load('success_listul138_eta=0001.npy')

WL001 = np.load('WLul138_eta=001.npy')
biasL001 = np.load('biasLul138_eta=001.npy')
costL001 = np.load('costLul138_eta=001.npy')
training_success_list001 = np.load('training_success_listul138_eta=001.npy')
success_list001 = np.load('success_listul138_eta=001.npy')

WL01 = np.load('WLul138_eta=01.npy')
biasL01 = np.load('biasLul138_eta=01.npy')
costL01 = np.load('costLul138_eta=01.npy')
training_success_list01 = np.load('training_success_listul138_eta=01.npy')
success_list01 = np.load('success_listul138_eta=01.npy')

# %%
N_epoch = 2000
test_W_ind = np.arange(0,N_epoch+1, 5)

# %%
plt.plot(test_W_ind, 1-success_list01, label=r'$\eta$=0.1')
plt.plot(test_W_ind, 1-success_list001, label=r'$\eta$=0.01')
plt.plot(test_W_ind, 1-success_list0001, label=r'$\eta$=0.001')
plt.plot(test_W_ind, 1-success_list00001, label=r'$\eta$=0.0001')

plt.legend()
plt.yscale('log')

# %%
plt.plot(np.arange(0,N_epoch), costL01, label=r'$\eta$=0.1')
plt.plot(np.arange(0,N_epoch), costL001, label=r'$\eta$=0.01')
plt.plot(np.arange(0,N_epoch), costL0001, label=r'$\eta$=0.001')
plt.plot(np.arange(0,N_epoch), costL00001, label=r'$\eta$=0.0001')

plt.legend()
plt.yscale('log')
