# %%
import numpy as np
import matplotlib.pyplot as plt

N_epoch = 1000
test_W_ind = np.arange(0,N_epoch+1, 5)

# %%
SL = np.asarray([np.load('success_list0.npy'), np.load('success_list1.npy'), 
                 np.load('success_list3.npy')])

# %%
SL.shape
# Out:
# (3, 201)

# %%
for k in range(0, SL.shape[0]):
    plt.plot(test_W_ind, SL[k,:])

plt.ylim(0.8, 1)
plt.xlim(0,1050)
# Out:
# (0.0, 1050.0)

# %%
plt.plot(test_W_ind, np.mean(SL, axis=0))
plt.ylim(0.8,1)
plt.xlim(0, 1050)
# Out:
# (0.0, 1050.0)
